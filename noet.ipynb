# %%
print("dkjaf")
# Out:
# dkjaf

# %% [markdown]
# 마크다운 만들기 힘드네

# %%
import matplotlib.pyplot as plt

# 데이터 생성
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# 선 그래프 그리기
plt.plot(x, y)

# 그래프 제목, 축 라벨 추가
plt.title('Example Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# 그래프 표시
plt.show()
